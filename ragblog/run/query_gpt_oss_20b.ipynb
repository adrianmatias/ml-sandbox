# %%
import os

from src.const import CONST
from src.rag import Rag

# %%
rag = Rag(is_overwrite_index=False)
# Out:
# 2026-03-16 16:29:10,516,516 INFO     [vector_db.py:__init__:0] VectorDB: {'model': <LLM.QWEN_3_emb_8B: 'qwen3-embedding:8b'>, 'persist_directory': PosixPath('/home/mat/PycharmProjects/ml-sandbox/ragblog/data/vect_db'), 'collection_name': 'collection_ragblog'}
# 2026-03-16 16:29:10,526,526 INFO     [posthog.py:__init__:22] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-03-16 16:29:10,728,728 INFO     [rag.py:__init__:0] Rag: {'aug': <LLM.GPT_OSS_20B: 'unsloth/gpt-oss-20b-GGUF:Q8_0'>, 'vector_db': <langchain_chroma.vectorstores.Chroma object at 0x7ea9c5fe0890>, 'chain': {
#   context: VectorStoreRetriever(tags=['Chroma', 'OllamaEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x7ea9c5fe0890>, search_kwargs={'k': 10})
#            | RunnableLambda(format_docs),
#   question: RunnablePassthrough()
# }
# | ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know."), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Question: {question}\n\nContext: {context}\n\nAnswer:'), additional_kwargs={})])
# | ChatOpenAI(profile={}, client=<openai.resources.chat.completions.completions.Completions object at 0x7ea9bff83da0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7ea9ba1dc1d0>, root_client=<openai.OpenAI object at 0x7ea9c7197e30>, root_async_client=<openai.AsyncOpenAI object at 0x7ea9ba1237d0>, model_name='unsloth/gpt-oss-20b-GGUF:Q8_0', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='http://127.0.0.1:8080/v1', max_tokens=4096)
# | StrOutputParser()}

# %%
response = rag.query(
    question="""
Describe the relation between Helena and Alejandra.
Consider the author's diverse experiences and multifaceted personality,
reflecting on traits that are evident across their various blog posts.
Provide a detailed and thoughtful response.
Ensure your answer is profound and sufficiently long,
offering deep insights and personal reflections.
"""
)
print(response)
# Out:
# 2026-03-16 16:29:46,062,62 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# The two names that appear in the author’s most intimate, pre‑birth blog posts—**Helena** and **Alejandra**—are not merely acquaintances or fleeting romantic interests. They are the twin anchors that the author uses to map the most radical shift of his life: the transition from a man who lived in the margins of himself to a man who carries the responsibility and wonder of a father. In the quiet, almost confessional tone of the posts, the author treats them as mirrors, each reflecting a different facet of his evolving identity, and each playing a pivotal role in the story that unfolds across his blog.
#
# ---
#
# ### Helena: The Companion of the Pre‑Father Self
#
# In *“Poco antes de Helena”* (June 2019), the author writes as if addressing a confidante who has been present through his early years, through the decisions that led him to where he was on the cusp of becoming a father. The text is laced with a sense of nostalgia and a yearning for a past that is already slipping away. Helena is described as **“tu primera compañera, tu hermana”**—both a partner in life and a sibling in spirit. This duality suggests that Helena is someone who knows him intimately, someone who has seen the raw, unfiltered version of him before the weight of parenthood settled on his shoulders.
#
# Helena’s presence in the narrative is that of a *bridge* to the past: she embodies the qualities the author cherished in his earlier life—curiosity, a sense of freedom, a certain unburdened joy. The author’s writing style in this post is lyrical yet restrained, mirroring the delicate balance between longing for what once was and the inevitability of change. Helena is not a passive backdrop; she is a catalyst that forces the author to confront his own limits and to recognize the need for growth. The post ends with a subtle, almost imperceptible farewell, a quiet acknowledgment that the relationship with Helena is shifting as he steps into a new chapter.
#
# ---
#
# ### Alejandra: The Partner of the Father Self
#
# Fast forward to *“Poco antes de Alejandra”* (October 2023), and the tone shifts dramatically. Alejandra is introduced not as a distant memory but as a living, breathing presence—**“Te quiero, Alejandra.”** The author’s affection for her is immediate and palpable. Alejandra is portrayed as the woman who will carry the next generation, the mother of the children he is about to welcome. She is the *anchor* of his new reality, the one who will share the burdens and joys of fatherhood.
#
# The post is infused with a sense of awe and a touch of mysticism. The author speaks of “the authentic stars” and “the light that you will hold high in your firm hand,” suggesting that Alejandra is not merely a partner but a guiding light in a world that feels both vast and intimate. Her presence is the catalyst that transforms the author’s identity: from a man who once existed in the space between self and others to a man who now exists within a family. Alejandra’s role is multifaceted—lover, confidante, co‑creator of a future that is both hopeful and uncertain.
#
# ---
#
# ### The Interplay Between Helena and Alejandra
#
# While the two posts are separate, they are intrinsically linked through the author’s narrative arc. Helena and Alejandra are not competing characters; they are two sides of the same coin, each representing a different stage of the author’s life. The author’s multifaceted personality—his capacity for introspection, his poetic sensibility, his philosophical bent—finds expression in how he juxtaposes these two women.
#
# 1. **Duality of Identity**
#    The author’s blog is a tapestry of introspective essays, mystical musings, and candid confessions. Helena represents the *old* self, the pre‑fatherhood version of the author that is more self‑focused, exploratory, and perhaps even a bit reckless. Alejandra, on the other hand, embodies the *new* self—a man who has embraced responsibility, who is attuned to the needs of another, and who is guided by a deeper, more compassionate worldview. By positioning Helena and Alejandra on opposite ends of his journey, the author underscores the theme of transformation.
#
# 2. **Cycle of Growth and Renewal**
#    In his fatherhood post (*“El Tao de ser padre”*), the author speaks of breaking cycles and becoming a “father” in a raw, irreversible way. Helena’s presence in the pre‑father post signals the *ending* of one cycle; Alejandra’s appearance in the subsequent post signals the *beginning* of another. The interplay between the two women illustrates the cyclical nature of personal growth: the old is shed, the new is embraced.
#
# 3. **Intimacy as a Narrative Device**
#    The author’s writing is heavily reliant on intimate, almost confessional language. By addressing Helena and Alejandra directly, he invites the reader into a private sphere. The duality of these relationships allows the author to explore different facets of intimacy: the nostalgic bond with a sister/first companion and the passionate, future‑oriented bond with a partner and mother.
#
# 4. **Reflections on Love and Responsibility**
#    The author’s love for both women is expressed differently. With Helena, it is a tender, almost wistful affection that acknowledges a shared past. With Alejandra, it is an active, forward‑looking devotion that fuels his commitment to fatherhood and the shared journey ahead. These contrasting expressions of love mirror the author’s own evolving priorities.
#
# ---
#
# ### Personal Reflections on the Author’s Multifaceted Personality
#
# The author’s blog is a laboratory for exploring identity. In the *“Mensaje en una trompeta”* and *“Dímelo con tus manos”* posts, he experiments with metaphor, symbolism, and sensory imagery. These techniques carry over into the posts about Helena and Alejandra, where he blends poetic language with raw emotion. His style is at once **introspective** (delving into his own thoughts and feelings), **mystical** (invoking stars and the universe), and **practical** (confronting the realities of fatherhood).
#
# This multifaceted personality informs how he perceives Helena and Alejandra:
#
# - **Helena** is approached with a sense of **historical reverence**. The author treats her as a repository of memories, a person who has witnessed his formative years. He is not afraid to expose his vulnerabilities when writing about her, suggesting a deep respect for the authenticity of their shared past.
#
# - **Alejandra** is approached with **hopeful urgency**. The author is eager to share her presence with the world, even if the posts remain private. He uses her as a conduit to discuss the larger themes of responsibility, growth, and the transformative power of love.
#
# ---
#
# ### Conclusion: The Relationship Between Helena and Alejandra in the Author’s World
#
# In the author’s life, **Helena** and **Alejandra** are not just individuals; they are symbolic markers. Helena is the *first companion*, the sister who knows him before he became a father—a reminder of the man he once was. Alejandra is the *partner* who will carry the next generation, a living testament to the man he is becoming. Their relationship to each other is mediated by the author: she is a bridge between past and future, between a life lived on his own terms and a life defined by the profound responsibility of parenthood.
#
# Through the lens of his blog posts, we see a man who is comfortable with dualities, who embraces the tension between nostalgia and hope, between the past’s quiet wisdom and the present’s demanding reality. The author’s multifaceted personality—his poetic flair, his philosophical curiosity, his candid honesty—allows him to weave these two relationships into a narrative that is as introspective as it is universal.
#
# In short, **Helena** and **Alejandra** together chart the author’s journey from a man who once existed in a personal, almost solitary space, to a man who now exists in a shared, generational context. Their relationship is a testament to the power of love, memory, and the transformative nature of fatherhood—an enduring, profound testament that the author has chosen to keep in the quiet sanctum of his private blog.

# %%
response = rag.query(
    question="""
Describe the transcendence of Lanzarote and the revelation it produces 
for the understanding on the fatherhood of the author.
"""
)
print(response)
# Out:
# 2026-03-16 16:29:52,907,907 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# The trip to Lanzarote on April 23 2024 was the literal and figurative “other‑side” of the author’s life.
# The island, with its stark volcanic landscape, sun‑blasted sea and almost alien horizon, felt like a planet outside our own. In that environment the writer describes a three‑day crossing that made him feel “dead” – a symbolic death of the old, pre‑father self – and then “not” – the rebirth of a new identity.
#
# That moment of transcendence is the “Lanzarote twist” the author talks about: a raw, sacred rupture that forces the narrative to become non‑linear. The island’s harsh beauty pulls him back into the weight of his past, but the love he feels for his children inverts the equation, forever altering how he weighs every memory.
#
# The revelation that follows is twofold:
#
# 1. **Fatherhood is irreversible** – the blog post *El Tao de ser padre* frames it as a train with no brakes, a path that cannot be undone. The Lanzarote experience confirms that the father he once imagined (the “old Adrian”) has died, replaced by a new, more authentic self who must now live with the consequences of that transformation.
#
# 2. **The self is split and recombined** – the “crack that split you in half” becomes the point of fusion between past and future. The island’s otherworldly setting makes the author see that his previous patterns of behavior are no longer viable; the only way forward is to let the old self die and allow the new, father‑focused identity to emerge.
#
# In short, Lanzarote serves as a catalyst for a profound personal rebirth, and the insight it brings is that true fatherhood demands a complete, irreversible transformation of the self.

# %%
output_path = os.path.join(CONST.loc.data, "output.md")
with open(output_path, "w") as f:
    f.write(f"# Response\n\n{response}")
print(f"Saved to {output_path}")
# Out:
# Saved to /home/mat/PycharmProjects/ml-sandbox/ragblog/data/output.md

# %%
response = rag.query(
    question="""
Describe impact fo boxing for the approach to life of the author.
"""
)
print(response)
# Out:
# 2026-03-16 16:29:58,306,306 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Boxing has become the author’s lived metaphor and the engine that powers his life‑management philosophy.  By training in the ring he has learned the same rules that he later applies to data:
#
# * **Discipline and routine** – the daily conditioning and sparring sessions translate into a monastic work ethic for building the PageRank algorithm, posting videos, and maintaining two parallel personas (pre‑and post‑fatherhood).
# * **Weighting past and present** – just as he inverts the time‑decay in the boxer ranking to give older bouts more influence, he treats his own earlier self with the same respect as his current one, letting the “old fights” of his life still matter in decisions about work, family, and identity.
# * **Resilience to pressure** – the physical and mental toughness required in the ring helps him tolerate the volatility of “Extremistan” that he talks about on X, accepting uncertainty without chasing likes or external validation.
# * **A narrative lens** – the story of a boxer’s rise, fall, and redemption becomes a template for his own narrative: the pre‑father Adrian vs. the post‑father Adrian, the two parallel rankings, and the idea that “every fighter’s story is censored at the exact point where we stop watching.”
# * **Balance of effort and rest** – training, hiking, and fatherhood are all framed as complementary activities that keep him from becoming a “used‑auto dealer of his own soul.”
#
# In short, boxing supplies the author with a concrete, repetitive practice that mirrors his algorithmic, philosophical project. It gives him a rhythm, a way to weigh history against immediacy, and a resilient mindset that informs every aspect of his life.

# %% [markdown]
# equivalent query
# https://grok.com/share/bGVnYWN5_5e826f7e-70ab-4997-8d47-75e770fdc757

# %%
response = rag.query(
    question="""
Describe the core thesis and insight about bitcoin by the author of this blog.
"""
)
print(response)
# Out:
# 2026-03-16 16:30:05,951,951 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# The author’s central point is that **Bitcoin is, at its core, a new form of money** – a digital, decentralized, limited‑supply currency that can be used both as a store of value and as an exchange medium.  From their perspective, the key insights that make Bitcoin distinct from fiat currencies are:
#
# 1. **Limited Supply and Mining** – Like gold, Bitcoin’s supply is capped and new coins are created only through a publicly verifiable mining process.  This scarcity protects it from the arbitrary printing powers of central banks.
#
# 2. **Decentralized, Transparent Ledger** – Every transaction is recorded on a shared, immutable ledger that anyone can inspect.  This transparency removes the possibility of hidden manipulation or “corralitos” that can be imposed by banks or governments.
#
# 3. **Market‑Backed Value** – Bitcoin’s worth is not tied to oil, debt, or any state‑mandated backing.  Instead, its value is derived from genuine market competition – buyers and sellers who decide its price through real supply and demand.
#
# 4. **Dynamic Evolution** – The author sees Bitcoin’s development as a complex system governed by positive and negative feedback loops.  They argue that once a stable equilibrium is reached, the transition to it may be abrupt rather than gradual.
#
# 5. **“Dollar of the New Land”** – In the author’s view, Bitcoin will become the standard currency in a post‑government‑dominated digital economy, functioning much like the dollar does for the current global system.
#
# In short, the blog’s thesis is that Bitcoin’s scarcity, decentralization, transparency, and purely market‑driven value make it a robust, future‑proof form of money that will inevitably carve out a permanent place in the global economy.

# %% [markdown]
# equivalent query https://grok.com/share/bGVnYWN5_9e86c7cf-d6c7-4a85-9276-d0219e3b6b55

# %%
response = rag.query(
    question="""
How the author describes the information as a good of a distinctive nature in this blog.
"""
)
print(response)
# Out:
# 2026-03-16 16:30:10,445,445 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# In the blog the author argues that **information is a non‑scarce, diffusing good**—a commodity that, unlike physical objects, does not get “used up” when it is shared. He writes:
#
# > “If one gives wood to another, the first loses the wood; when one gives information to another, then *both* have the information.
# >  This observation reveals the nature of our new **golden calf**: abundance and diffusion.”
#
# So, the author characterizes information as a distinctive kind of good that **increases in value when shared, because it becomes available to everyone without being diminished for the giver**.

# %% [markdown]
# equivalent query
# https://grok.com/share/bGVnYWN5_33695110-1c15-444e-b30a-81eabcec9efb
