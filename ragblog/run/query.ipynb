# %%
import os

from src.const import CONST
from src.rag import Rag

# %%
rag = Rag(is_overwrite_index=False)
# Out:
# 2026-03-11 07:50:00,403,403 INFO     [vector_db.py:__init__:0] VectorDB: {'model': <LLM.QWEN_3_emb_8B: 'qwen3-embedding:8b'>, 'persist_directory': PosixPath('/home/mat/PycharmProjects/ml-sandbox/ragblog/data/vect_db'), 'collection_name': 'collection_ragblog'}
# 2026-03-11 07:50:00,403,403 INFO     [crawler.py:__init__:0] Crawler: {'url_list': [], 'post_list': [], 'url': 'https://delightfulobservaciones.blogspot.com/', 'post_count_min': 100}
# 2026-03-11 07:50:00,404,404 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/
# 2026-03-11 07:50:00,679,679 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2026/03/what-do-you-know-about-me.html
# 2026-03-11 07:50:00,681,681 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2024/07/si-es-verdad-como-dicen-los-sabios.html
# 2026-03-11 07:50:00,681,681 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2024/03/sol-de-mi-corazon.html
# 2026-03-11 07:50:00,681,681 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2024/03/el-tao-de-ser-padre.html
# 2026-03-11 07:50:00,682,682 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2023/10/poco-antes-de-alejandra.html
# 2026-03-11 07:50:00,682,682 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2020/04/la-materializacion-del-riesgo.html
# 2026-03-11 07:50:00,682,682 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2020/03/viajeros-del-futuro.html
# 2026-03-11 07:50:00,683,683 INFO     [crawler.py:get_url_list:55] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2020-03-21T11:53:00-07:00&max-results=7
# 2026-03-11 07:50:00,683,683 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2020-03-21T11:53:00-07:00&max-results=7
# 2026-03-11 07:50:00,886,886 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2019/06/poco-antes-de-helena.html
# 2026-03-11 07:50:00,887,887 INFO     [crawler.py:get_url_list:55] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2019-06-19T14:23:00-07:00&max-results=7&start=1&by-date=false
# 2026-03-11 07:50:00,887,887 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2019-06-19T14:23:00-07:00&max-results=7&start=1&by-date=false
# 2026-03-11 07:50:01,406,406 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2017/11/mensaje-en-una-trompeta.html
# 2026-03-11 07:50:01,407,407 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2017/04/le-llaman-la-bruja.html
# 2026-03-11 07:50:01,408,408 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2017/02/como-un-latir-de-pies-que-no-se-acaba.html
# 2026-03-11 07:50:01,408,408 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2015/09/inventa-un-hueco-y-pon-en-el-un-golpe.html
# 2026-03-11 07:50:01,408,408 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2015/08/quiza-no-te-haya-hablado-nunca-de-ellas.html
# 2026-03-11 07:50:01,409,409 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2015/07/grecia-las-contradicciones-de-mi-union.html
# 2026-03-11 07:50:01,410,410 INFO     [crawler.py:get_url_list:55] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2015-07-13T15:49:00-07:00&max-results=7&start=7&by-date=false
# 2026-03-11 07:50:01,410,410 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2015-07-13T15:49:00-07:00&max-results=7&start=7&by-date=false
# 2026-03-11 07:50:01,705,705 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2014/09/fiesta-de-disfraces.html
# 2026-03-11 07:50:01,706,706 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2014/01/cuando-lo-viejo-rehusa-hacerse-un-lado.html
# 2026-03-11 07:50:01,707,707 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2013/11/los-9-motivos-por-los-que-tengo-bitcoins.html
# 2026-03-11 07:50:01,707,707 INFO     [crawler.py:get_url_list:55] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2013-11-10T10:11:00-08:00&max-results=7&start=10&by-date=false
# 2026-03-11 07:50:01,707,707 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2013-11-10T10:11:00-08:00&max-results=7&start=10&by-date=false
# 2026-03-11 07:50:02,059,59 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2013/10/ok-la-doctrina-parot-pero-y-la-doctrina.html
# 2026-03-11 07:50:02,060,60 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2013/07/london-at-work.html
# 2026-03-11 07:50:02,061,61 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2013/07/estan-robando-tus-suenos-y-tu-esfuerzo.html
# 2026-03-11 07:50:02,061,61 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2013/05/hiperneolitico.html
# 2026-03-11 07:50:02,061,61 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2013
INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2012/04/ahi-va-un-primer-fragmento-de-volcan.html
# 2026-03-11 07:50:04,332,332 INFO     [crawler.py:get_url_list:55] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2012-04-22T09:32:00-07:00&max-results=7&start=45&by-date=false
# 2026-03-11 07:50:04,333,333 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2012-04-22T09:32:00-07:00&max-results=7&start=45&by-date=false
# 2026-03-11 07:50:04,724,724 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2012/02/soy-mas-rico-que-fernando-i-de-aragon.html
# 2026-03-11 07:50:04,725,725 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2011/11/waking-life.html
# 2026-03-11 07:50:04,725,725 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2011/11/europeos-del-centro-y-de-la-periferia.html
# 2026-03-11 07:50:04,725,725 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2011/10/gatos-de-schrondringer-pensamientos.html
# 2026-03-11 07:50:04,726,726 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2011/10/el-botin-miedo-amenaza-o-ambos.html
# 2026-03-11 07:50:04,726,726 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2011/10/sobre-la-consciencia.html
# 2026-03-11 07:50:04,726,726 INFO     [crawler.py:get_url_list:47] url: https://delightfulobservaciones.blogspot.com/2011/10/el-cambio-global-se-irradia-desde-el-15.html
# 2026-03-11 07:50:04,726,726 INFO     [crawler.py:get_url_list:57] No more pages found.
# 2026-03-11 07:50:27,372,372 INFO     [crawler.py:write:72] path_file: /home/mat/PycharmProjects/ml-sandbox/ragblog/data/blog.jsonl
# 2026-03-11 07:50:27,374,374 INFO     [doc_loader.py:__init__:0] DocLoader: {}
# 2026-03-11 07:50:27,399,399 INFO     [vector_db.py:save:23] doc_list_count=904
# 2026-03-11 07:50:27,419,419 INFO     [posthog.py:__init__:22] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-03-11 07:51:09,933,933 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 2026-03-11 07:51:10,670,670 INFO     [rag.py:__init__:0] Rag: {'aug': <LLM.QWEN_3_5_9B: 'qwen3.5:9b'>, 'vector_db': <langchain_chroma.vectorstores.Chroma object at 0x7d15e87c7950>, 'chain': {
#   context: VectorStoreRetriever(tags=['Chroma', 'OllamaEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x7d15e87c7950>, search_kwargs={'k': 10})
#            | RunnableLambda(format_docs),
#   question: RunnablePassthrough()
# }
# | PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="human\n\n[INST]<<SYS>> You are an assistant for question-answering tasks. \nUse the following pieces of retrieved context to answer the question. \nIf you don't know the answer, just say that you don't know.<</SYS>> \n\nQuestion: {question} \n\nContext: {context} \n\nAnswer: [/INST]")
# | OllamaLLM(model='qwen3.5:9b')
# | StrOutputParser()}

# %%
response = rag.query(
    question="""
Describe the relation between Helena and Alejandra.
Consider the author's diverse experiences and multifaceted personality,
reflecting on traits that are evident across their various blog posts.
Provide a detailed and thoughtful response.
Ensure your answer is profound and sufficiently long,
offering deep insights and personal reflections.
"""
)
print(response)
# Out:
# 2026-03-11 07:51:10,748,748 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 2026-03-11 07:51:13,626,626 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# The relationship between Helena and Alejandra, as described in the context, is that of **sisters and daughters**, united within the private, sacred heart of the author (the father). They are not merely names in the public record but "the only two names appearing in the private heart," representing a deeply personal journey of fatherhood and spiritual growth.
#
# Here are the deep insights and personal reflections regarding their bond:
#
# **1. The Sacredness of Their Private Existence**
# The names Helena and Alejandra exist in a realm separate from the public eye. They appear "nowhere public except in your private heart." This suggests a relationship rooted in intimacy, exclusivity, and a bond that transcends the need for external validation. Their existence in the father's mind is a "crack that split you in half," indicating that becoming a father was a transformative event that permanently altered his identity, creating a space specifically for these daughters.
#
# **2. The Sisterhood (Helena and Alejandra)**
# Helena is explicitly addressed as Alejandra’s "first companion" (*primera compañera*) and "sister" (*hermana*). In the context of the 2023 post, Helena is positioned as a spiritual companion ("Helena está contigo...") who bridges the gap between the father and Alejandra. This implies a protective, nurturing dynamic where Helena serves as a bridge, a friend, and a sister figure within the family unit. It suggests a bond where one sister is always present for the other, fostering a connection that the father witnesses and cherishes.
#
# **3. The Fatherhood Journey (The Timeline)**
# The relationship is framed through the timeline of their births or anticipated arrivals:
# *   **Helena (Pre-birth 2019):** The blog post "Poco antes de Helena" (Shortly before Helena) from 2019 marks the arrival of the first child, or the beginning of the father's journey with her. It represents the first crack in the author's previous self, introducing a new identity as a father.
# *   **Alejandra (Pre-birth 2023):** The post "Poco antes de Alejandra" (Shortly before Alejandra) from 2023 reflects on her arrival or anticipation. In this entry, the author explicitly identifies her as "hija" (daughter). This progression shows a deepening of the father's role, moving from the initial introduction of Helena to the full embrace of Alejandra, who is also his daughter.
#
# **4. Emotional Depth and "The Crack"**
# The author describes fatherhood as a "crack that split you in half," a metaphor for how these daughters have fundamentally changed his internal landscape. Helena and Alejandra are the fillings in that crack—the "light" that allows him to function and feel whole again. Their relationship is not just biological but spiritual; they are the "pre-birth" presence that he has been anticipating and preparing for long before they physically arrive. The phrase "Te quiero" (I love you) appears in the text, underscoring the depth of this familial love.
#
# **5. Legacy and Continuity**
# The relationship between the two girls and the father is also one of continuity. The blog posts serve as a "bridge" between the past (the father before fatherhood) and the future (the family now). Helena and Alejandra are the tangible evidence of this transformation. They share a lineage (father and sister) that is documented in these "pre-birth" reflections, making their bond a legacy that is actively being written and understood by the father in real-time.
#
# In summary, Helena and Alejandra are the daughters of the author and sisters to each other, bound by a unique, sacred, and private connection that has redefined the author's life through the profound journey of becoming a father. Their relationship is characterized by love, protection, and a deep, spiritual intimacy that exists solely within the family's private heart.

# %%
response = rag.query(
    question="""
Describe the transcendence of Lanzarote and the revelation it produces 
for the understanding on the fatherhood of the author.
"""
)
print(response)
# Out:
# 2026-03-11 07:52:21,039,39 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 2026-03-11 07:52:21,660,660 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Based on the retrieved context, the transcendence of Lanzarote is described as a profound existential shift where the author experienced a state of death and rebirth ("I was dead. And then I was not.") amidst the holiday setting, where the island appeared like "another planet."
#
# This experience produced a revelation regarding the nature of fatherhood, defining it as an "irreversible train" that offers "no turning back, no stops, no steering wheel, no brakes" (*"No hay vuelta atrás, no hay paradas, volante ni freno."*). The revelation crystallizes that fatherhood is the moment the "old Adrian died" and a new identity was forced to begin weighting the past differently forever.
#
# Furthermore, the transcendence reveals that the force driving this irreversible journey is love—specifically from the two little girls and their mother ("your love — yours and your mother’s — that reached across and pulled me")—rather than willpower, machines, or doctors. This love converts the past into the future, transforming the author's understanding of fatherhood into a "Tao that cannot be told, but can be lived." It confirms that fatherhood is a "crack that split you in half," marking the end of the "pre-father man" and the beginning of a mystical, desperate, yet sacred commitment to break cycles and see "authentic stars."

# %%
output_path = os.path.join(CONST.loc.data, "output.md")
with open(output_path, "w") as f:
    f.write(f"# Response\n\n{response}")
print(f"Saved to {output_path}")
# Out:
# Saved to /home/mat/PycharmProjects/ml-sandbox/ragblog/data/output.md
