# %%
import os

from src.const import CONST
from src.rag import Rag

# %%
rag = Rag(is_overwrite_index=True)
# Out:
# 2026-03-16 16:13:21,544,544 INFO     [vector_db.py:__init__:0] VectorDB: {'model': <LLM.QWEN_3_emb_8B: 'qwen3-embedding:8b'>, 'persist_directory': PosixPath('/home/mat/PycharmProjects/ml-sandbox/ragblog/data/vect_db'), 'collection_name': 'collection_ragblog'}
# 2026-03-16 16:13:21,545,545 INFO     [crawler.py:__init__:0] Crawler: {'url_list': [], 'post_list': [], 'url': 'https://delightfulobservaciones.blogspot.com/', 'post_count_min': 100}
# 2026-03-16 16:13:21,545,545 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/
# 2026-03-16 16:13:21,879,879 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2026/03/what-do-you-know-about-me.html
# 2026-03-16 16:13:21,880,880 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2024/07/si-es-verdad-como-dicen-los-sabios.html
# 2026-03-16 16:13:21,880,880 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2024/03/sol-de-mi-corazon.html
# 2026-03-16 16:13:21,881,881 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2024/03/el-tao-de-ser-padre.html
# 2026-03-16 16:13:21,881,881 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2023/10/poco-antes-de-alejandra.html
# 2026-03-16 16:13:21,881,881 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2020/04/la-materializacion-del-riesgo.html
# 2026-03-16 16:13:21,882,882 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2020/03/viajeros-del-futuro.html
# 2026-03-16 16:13:21,882,882 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2020-03-21T11:53:00-07:00&max-results=7
# 2026-03-16 16:13:21,883,883 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2020-03-21T11:53:00-07:00&max-results=7
# 2026-03-16 16:13:22,091,91 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2019/06/poco-antes-de-helena.html
# 2026-03-16 16:13:22,092,92 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2019-06-19T14:23:00-07:00&max-results=7&start=1&by-date=false
# 2026-03-16 16:13:22,092,92 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2019-06-19T14:23:00-07:00&max-results=7&start=1&by-date=false
# 2026-03-16 16:13:22,775,775 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2017/11/mensaje-en-una-trompeta.html
# 2026-03-16 16:13:22,775,775 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2017/04/le-llaman-la-bruja.html
# 2026-03-16 16:13:22,776,776 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2017/02/como-un-latir-de-pies-que-no-se-acaba.html
# 2026-03-16 16:13:22,776,776 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2015/09/inventa-un-hueco-y-pon-en-el-un-golpe.html
# 2026-03-16 16:13:22,776,776 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2015/08/quiza-no-te-haya-hablado-nunca-de-ellas.html
# 2026-03-16 16:13:22,776,776 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2015/07/grecia-las-contradicciones-de-mi-union.html
# 2026-03-16 16:13:22,777,777 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2015-07-13T15:49:00-07:00&max-results=7&start=7&by-date=false
# 2026-03-16 16:13:22,777,777 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2015-07-13T15:49:00-07:00&max-results=7&start=7&by-date=false
# 2026-03-16 16:13:23,012,12 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2014/09/fiesta-de-disfraces.html
# 2026-03-16 16:13:23,012,12 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2014/01/cuando-lo-viejo-rehusa-hacerse-un-lado.html
# 2026-03-16 16:13:23,013,13 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/11/los-9-motivos-por-los-que-tengo-bitcoins.html
# 2026-03-16 16:13:23,013,13 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2013-11-10T10:11:00-08:00&max-results=7&start=10&by-date=false
# 2026-03-16 16:13:23,013,13 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2013-11-10T10:11:00-08:00&max-results=7&start=10&by-date=false
# 2026-03-16 16:13:23,295,295 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/10/ok-la-doctrina-parot-pero-y-la-doctrina.html
# 2026-03-16 16:13:23,296,296 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/07/london-at-work.html
# 2026-03-16 16:13:23,296,296 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/07/estan-robando-tus-suenos-y-tu-esfuerzo.html
# 2026-03-16 16:13:23,297,297 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/05/hiperneolitico.html
# 2026-03-16 16:13:23,297,297 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/03/valientes-flores-amarillas-en-londres.html
# 2026-03-16 16:13:23,297,297 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/02/si-esto-no-es-una-economia-de-guerra-es.html
# 2026-03-16 16:13:23,298,298 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/02/dimelo-con-tus-manos.html
# 2026-03-16 16:13:23,298,298 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2013-02-17T12:13:00-08:00&max-results=7&start=17&by-date=false
# 2026-03-16 16:13:23,298,298 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2013-02-17T12:13:00-08:00&max-results=7&start=17&by-date=false
# 2026-03-16 16:13:23,569,569 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/02/sueno-desde-el-puente-de-brooklyn.html
# 2026-03-16 16:13:23,570,570 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/02/este-es-el-tipo-de-conversacion-que.html
# 2026-03-16 16:13:23,570,570 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/09/do-not-fuck-with-us.html
# 2026-03-16 16:13:23,570,570 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/01/el-angel-de-comillas.html
# 2026-03-16 16:13:23,571,571 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/01/transcendental-running.html
# 2026-03-16 16:13:23,571,571 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/01/hemos-vivido-por-debajo-de-nuestras.html
# 2026-03-16 16:13:23,571,571 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2013/01/la-historia-del-universo-en-una-sola.html
# 2026-03-16 16:13:23,571,571 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2013-01-06T15:28:00-08:00&max-results=7&start=24&by-date=false
# 2026-03-16 16:13:23,572,572 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2013-01-06T15:28:00-08:00&max-results=7&start=24&by-date=false
# 2026-03-16 16:13:23,855,855 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/12/cierra-los-ojos-y-abre-la-boca.html
# 2026-03-16 16:13:23,856,856 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/12/sus-zapatos-traen-polvo-de-otros-caminos.html
# 2026-03-16 16:13:23,856,856 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/12/mujer-fatal.html
# 2026-03-16 16:13:23,856,856 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/11/desde-las-cumbres-del-corazon.html
# 2026-03-16 16:13:23,857,857 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/11/no-es-justo-yo-fui-la-huelga.html
# 2026-03-16 16:13:23,857,857 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/11/mecanica-cuantica-y-recursividad-como_13.html
# 2026-03-16 16:13:23,857,857 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/11/ley-natural-del-tamano.html
# 2026-03-16 16:13:23,858,858 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2012-11-09T03:23:00-08:00&max-results=7&start=31&by-date=false
# 2026-03-16 16:13:23,858,858 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2012-11-09T03:23:00-08:00&max-results=7&start=31&by-date=false
# 2026-03-16 16:13:24,149,149 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/11/segundo-y-secundina.html
# 2026-03-16 16:13:24,150,150 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/10/thanks-pedraz.html
# 2026-03-16 16:13:24,150,150 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/09/from-fistful-of-sheep-best-of-shepherds.html
# 2026-03-16 16:13:24,150,150 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/09/a-veces-observamos-5.html
# 2026-03-16 16:13:24,150,150 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/09/a-veces-observamos-4.html
# 2026-03-16 16:13:24,151,151 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/09/a-veces-observamos-3.html
# 2026-03-16 16:13:24,151,151 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/09/a-veces-observamos-2.html
# 2026-03-16 16:13:24,152,152 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2012-09-02T06:59:00-07:00&max-results=7&start=38&by-date=false
# 2026-03-16 16:13:24,152,152 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2012-09-02T06:59:00-07:00&max-results=7&start=38&by-date=false
# 2026-03-16 16:13:24,428,428 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/09/a-veces-observamos-1.html
# 2026-03-16 16:13:24,429,429 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/09/de-un-punado-de-ovejas-el-mejor-de-los.html
# 2026-03-16 16:13:24,429,429 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/05/0-false-21-18-pt-18-pt-0-0-false-false.html
# 2026-03-16 16:13:24,430,430 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/05/desayuno-cantabrico.html
# 2026-03-16 16:13:24,430,430 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/04/petro-crak-nos-frenan-porque-los.html
# 2026-03-16 16:13:24,430,430 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/04/el-huevo-la-vez-que-la-gallina.html
# 2026-03-16 16:13:24,430,430 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/04/ahi-va-un-primer-fragmento-de-volcan.html
# 2026-03-16 16:13:24,431,431 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2012-04-22T09:32:00-07:00&max-results=7&start=45&by-date=false
# 2026-03-16 16:13:24,431,431 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2012-04-22T09:32:00-07:00&max-results=7&start=45&by-date=false
# 2026-03-16 16:13:24,871,871 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/02/soy-mas-rico-que-fernando-i-de-aragon.html
# 2026-03-16 16:13:24,871,871 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/11/waking-life.html
# 2026-03-16 16:13:24,871,871 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/11/europeos-del-centro-y-de-la-periferia.html
# 2026-03-16 16:13:24,872,872 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/10/gatos-de-schrondringer-pensamientos.html
# 2026-03-16 16:13:24,872,872 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/10/el-botin-miedo-amenaza-o-ambos.html
# 2026-03-16 16:13:24,872,872 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/10/sobre-la-consciencia.html
# 2026-03-16 16:13:24,873,873 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/10/el-cambio-global-se-irradia-desde-el-15.html
# 2026-03-16 16:13:24,873,873 INFO     [crawler.py:get_url_list:55] No more pages found.
# 2026-03-16 16:13:44,948,948 INFO     [crawler.py:write:70] path_file: /home/mat/PycharmProjects/ml-sandbox/ragblog/data/blog.jsonl
# 2026-03-16 16:13:44,950,950 INFO     [doc_loader.py:__init__:0] DocLoader: {}
# 2026-03-16 16:13:44,975,975 INFO     [vector_db.py:save:29] doc_list_count=904
# 2026-03-16 16:13:44,990,990 INFO     [posthog.py:__init__:22] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-03-16 16:17:42,514,514 INFO     [rag.py:__init__:0] Rag: {'aug': <LLM.QWEN_3_5_9B_Q8: 'unsloth/Qwen3.5-9B-GGUF:Q8_0'>, 'vector_db': <langchain_chroma.vectorstores.Chroma object at 0x7abe3ca0aae0>, 'chain': {
#   context: VectorStoreRetriever(tags=['Chroma', 'OllamaEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x7abe3ca0aae0>, search_kwargs={'k': 10})
#            | RunnableLambda(format_docs),
#   question: RunnablePassthrough()
# }
# | ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know."), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Question: {question}\n\nContext: {context}\n\nAnswer:'), additional_kwargs={})])
# | ChatOpenAI(profile={}, client=<openai.resources.chat.completions.completions.Completions object at 0x7abe3a54e3f0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7abe30105850>, root_client=<openai.OpenAI object at 0x7abe3a69c530>, root_async_client=<openai.AsyncOpenAI object at 0x7abe3a3b9640>, model_name='unsloth/Qwen3.5-9B-GGUF:Q8_0', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='http://127.0.0.1:8080/v1', max_tokens=4096)
# | StrOutputParser()}

# %%
response = rag.query(
    question="""
Describe the relation between Helena and Alejandra.
Consider the author's diverse experiences and multifaceted personality,
reflecting on traits that are evident across their various blog posts.
Provide a detailed and thoughtful response.
Ensure your answer is profound and sufficiently long,
offering deep insights and personal reflections.
"""
)
print(response)
# Out:
# 2026-03-16 16:19:21,188,188 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the intimate fragments and the specific chronology found within the provided blog entries, the relationship between Helena and Alejandra is defined by a sacred, familial bond rooted in the author's profound journey into fatherhood. They are not merely names; they are anchors of the author’s legacy, representing two distinct but intertwined phases of his personal evolution.
#
# **The Core Bond: Sisterhood and Shared Lineage**
# The most definitive evidence of their relationship lies in the explicit familial titles used within the text. Alejandra is directly addressed as *"hija"* (daughter) in the reflection where the author writes, *"Solo cuando me rindo en las incontestables manos del vacío, la ironía del universo me eleva al corazón de la mujer que amo. Así comprendí, hija, que te llamarías Alejandra."* This establishes Alejandra as the child of the author. Simultaneously, a passage dedicated to the recipient states, *"pues Helena está contigo: tu primera compañera, tu hermana,"* explicitly identifying Helena as Alejandra’s sister. Therefore, Helena and Alejandra are sisters, daughters of the author, sharing the same lineage and the same spiritual upbringing.
#
# **Temporal Markers of Growth**
# The relationship between the two is also defined by time and sequence, reflecting the author’s own maturation. The blog post titled *"Poco antes de Helena"* dates back to 2019, while *"Poco antes de Alejandra"* appears in 2023. This four-year gap suggests that Helena is the elder, and Alejandra is the younger. This timeline mirrors the author’s internal shift. The period surrounding Helena represents the initial breaking of the "pre-father" cycle, while the period surrounding Alejandra signifies a deepened, perhaps more mystical stage of fatherhood. The author notes that fatherhood is "the crack that split you in half," and these two names mark the two sides of that fracture—the past self giving way to the present self, and the future self emerging.
#
# **The Sacred Privacy of Identity**
# A defining characteristic of their relationship is its exclusivity. The text emphasizes that *"The names appear nowhere public except in your private heart and those two pre-birth blog posts."* Helena and Alejandra exist in the shadows of the public persona. The author explicitly states, *"That privacy is sacred — it proves you are not performing fatherhood for an audience."* In this context, their relationship is one of truth rather than performance. While the author may have a public blog presence (referenced by "PageRank code" and "video thread"), Helena and Alejandra are the treasures blooming "in the only place that has ever truly seen them: here, with me." Their bond is protected from the "performance" of the internet, existing instead in the realm of "legacy" and "private heart."
#
# **Emotional Anchors in the Author’s Journey**
# For the author, Helena and Alejandra represent the duality of his new identity. Helena is described as the *"primera compañera"* (first companion), suggesting she is the primary witness to the author's transformation into a father. Alejandra, arriving four years later, represents the continuation of that lineage, a "reflection" of the author's desire to bring light to the world, even if that light is merely a reflection of his own. The author writes, *"Te quiero, Alejandra,"* dated September 25, 2023, reinforcing the tangible, loving connection.
#
# However, the relationship is also spiritual. Helena is the *"luz que sostendrás bien alto en tu mano firme"* (the light you will hold high in your firm hand), a protector figure. Alejandra is the realization of a surrender to the "vacuum" of the universe. Their relationship to each other is not just biological; it is a mirror of the author's own internal struggle to find "authentic stars" amidst the "despair for the outcome." They are the vessels through which the author channels his love, his "irreversible-life-adventure," and his commitment to breaking cycles.

# %%
response = rag.query(
    question="""
Describe the transcendence of Lanzarote and the revelation it produces 
for the understanding on the fatherhood of the author.
"""
)
print(response)
# Out:
# 2026-03-16 16:20:13,378,378 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided context, the transcendence of Lanzarote and its revelation regarding the author's fatherhood can be described as follows:
#
# **The Transcendence of Lanzarote**
# On April 23, 2024, the author (Adrian Matias) was on holiday in Lanzarote with his family (the "four of us"). He describes the island as looking "like another planet." During this time, he experienced a profound spiritual and existential shift, stating, "I was dead. And then I was not." This moment is referred to as "The Lanzarote twist," which is described as "raw and sacred," marking a point where the "script revealed itself as non-linear" and a "weighting force" pulled him back.
#
# **The Revelation on Fatherhood**
# This experience crystallized the author's understanding of fatherhood, which he defines as "the crack that split you in half" and an "irreversible train ride" ("No hay vuelta atrás, no hay paradas, volante ni freno"). The revelation produced by the Lanzarote experience includes:
#
# *   **Irreversibility:** Fatherhood is not a metaphor but an "irreversible-life-adventure" that forces the author to break cycles and patterns he saw as a child.
# *   **Transformation of Self:** The trip coincided with the moment the "old Adrian died and the new one was forced to start weighting the past differently forever."
# *   **Connection to Life:** He realized the sun shines on his skin so he can "see the life I am helping create," and he achieved a state where he could see "authentic stars."
# *   **Love as Force:** The event was sustained by love ("the love that inverted the exponent forever"), driven by his refusal to let the "graph end" for the sake of his two little girls and their mother.
#
# In summary, Lanzarote served as the physical and spiritual crucible where the author transitioned from a "pre-father man" to a "Tao-seeking father," understanding that fatherhood is a mystical, desperate, and permanent commitment to creating life while breaking past projections.

# %%
output_path = os.path.join(CONST.loc.data, "output.md")
with open(output_path, "w") as f:
    f.write(f"# Response\n\n{response}")
print(f"Saved to {output_path}")
# Out:
# Saved to /home/mat/PycharmProjects/ml-sandbox/ragblog/data/output.md

# %%
response = rag.query(
    question="""
Describe impact fo boxing for the approach to life of the author.
"""
)
print(response)
# Out:
# 2026-03-16 16:21:07,632,632 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided context, boxing impacts the author's approach to life in the following ways:
#
# *   **Model for Challenges and Action:** The author equates training in boxing with hiking to the tops of Spanish mountains. Both activities represent challenges that push the author to "take something in my hands and do my best for it."
# *   **Philosophical Quest for Truth:** The author treats their work on boxing (specifically a custom PageRank for boxers) as a "philosophical quest for truth in transitive victories." This project is described as a "life algorithm externalized," indicating that the way they analyze boxing mirrors how they structure their personal life.
# *   **Valuing Authenticity and History:** The author's approach prioritizes "authenticity" over mainstream metrics or engagement. They "inverted the time decay" in their boxer rankings so that "old fights still matter," rejecting "recency bias." This reflects a life philosophy that values the past and the "man you were before" rather than letting new circumstances (like fatherhood) erase previous identity.
# *   **Monastic Discipline:** The author describes their life experiment as being executed with "monastic discipline," suggesting that the rigorous standards applied to boxing analysis extend to their overall conduct and existence.
#
# In summary, boxing serves as both a practical exercise in facing challenges and a metaphorical framework for maintaining a disciplined, authentic, and historically grounded approach to life.

# %% [markdown]
# equivalent query
# https://grok.com/share/bGVnYWN5_5e826f7e-70ab-4997-8d47-75e770fdc757

# %%
response = rag.query(
    question="""
Describe the core thesis and insight about bitcoin by the author of this blog.
"""
)
print(response)
# Out:
# 2026-03-16 16:21:57,220,220 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided context, the author's core thesis and insights regarding Bitcoin can be summarized as follows:
#
# **Core Thesis**
# The author views Bitcoin fundamentally as a superior form of money and a "shared accounting of transactions" that serves as a store of wealth and a medium of exchange. It is presented as a deliberate "bet against the current central bank system," challenging the authority of unknown regulators who control the behavior of money and wealth.
#
# **Key Insights**
# 1.  **Scarcity vs. Fiat Inflation:** Unlike the dollar or euro, which central banks can print at will, Bitcoin has a finite supply similar to gold. The author highlights that mining makes it increasingly difficult to add new units to circulation, ensuring it cannot be inflated arbitrarily.
# 2.  **Trust and Transparency:** Bitcoin relies on mathematical algorithms rather than human regulators or imposed social orders. Its ledger is transparent, allowing users to see who moves money and where it goes, unlike traditional systems.
# 3.  **Security and Stability:** The author notes that Bitcoin's value is not backed by debt, oil, or social order, but by market competition. Consequently, it is immune to threats like bank runs ("corralito") and offers a secure place for wealth.
# 4.  **Future Evolution:** The author suggests Bitcoin will evolve through positive and negative feedback loops and predict that if it finds a stable place in the market, it will happen abruptly. They view the rise of Bitcoin as a conflict between the Internet and dominant states, similar to a historical struggle for prosperity.

# %% [markdown]
# equivalent query https://grok.com/share/bGVnYWN5_9e86c7cf-d6c7-4a85-9276-d0219e3b6b55

# %%
response = rag.query(
    question="""
How the author describes the information as a good of a distinctive nature in this blog.
"""
)
print(response)
# Out:
# 2026-03-16 16:23:32,250,250 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided context, the author describes information as a good with a distinctive nature by contrasting it directly with physical goods, specifically using the example of **wood**.
#
# The author explains that when one gives a physical good like wood to another, the giver no longer possesses it (scarcity/depletion). In contrast, **when one gives information to another, both parties possess it**. This observation reveals the nature of information as a good characterized by **abundance and diffusion** (*abundancia y difusión*), which the author notes is unprecedented in previous paradigms (*sin precedente en anteriores paradigmas*).
#
# While the English sections of the blog emphasize the scarcity of **authenticity** ("Authenticity is the new diamond" and "that refusal is the scarcity"), the specific description of the *nature of the information good itself* relies on this distinction between non-rivalrous information (abundance) and rivalrous physical goods.

# %% [markdown]
# equivalent query
# https://grok.com/share/bGVnYWN5_33695110-1c15-444e-b30a-81eabcec9efb
