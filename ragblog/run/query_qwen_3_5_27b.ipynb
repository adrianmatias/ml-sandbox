# %%
import os

from src.const import CONST
from src.rag import Rag

# %%
rag = Rag(is_overwrite_index=False)
# Out:
# 2026-03-16 15:32:08,026,26 INFO     [vector_db.py:__init__:0] VectorDB: {'model': <LLM.QWEN_3_emb_8B: 'qwen3-embedding:8b'>, 'persist_directory': PosixPath('/home/mat/PycharmProjects/ml-sandbox/ragblog/data/vect_db'), 'collection_name': 'collection_ragblog'}
# 2026-03-16 15:32:08,040,40 INFO     [posthog.py:__init__:22] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-03-16 15:32:08,248,248 INFO     [rag.py:__init__:0] Rag: {'aug': <LLM.QWEN_3_5_27B_Q3: 'unsloth/Qwen3.5-27B-GGUF:Q3_K_S'>, 'vector_db': <langchain_chroma.vectorstores.Chroma object at 0x710b0d5d97f0>, 'chain': {
#   context: VectorStoreRetriever(tags=['Chroma', 'OllamaEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x710b0d5d97f0>, search_kwargs={'k': 10})
#            | RunnableLambda(format_docs),
#   question: RunnablePassthrough()
# }
# | ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know."), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Question: {question}\n\nContext: {context}\n\nAnswer:'), additional_kwargs={})])
# | ChatOpenAI(profile={}, client=<openai.resources.chat.completions.completions.Completions object at 0x710b0cc8ed50>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x710b07f68e90>, root_client=<openai.OpenAI object at 0x710b0cc87860>, root_async_client=<openai.AsyncOpenAI object at 0x710b0cc8c080>, model_name='unsloth/Qwen3.5-27B-GGUF:Q3_K_S', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='http://127.0.0.1:8080/v1', max_tokens=4096)
# | StrOutputParser()}

# %%
response = rag.query(
    question="""
Describe the relation between Helena and Alejandra.
Consider the author's diverse experiences and multifaceted personality,
reflecting on traits that are evident across their various blog posts.
Provide a detailed and thoughtful response.
Ensure your answer is profound and sufficiently long,
offering deep insights and personal reflections.
"""
)
print(response)
# Out:
# 2026-03-16 15:36:03,734,734 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided context, the relationship between Helena and Alejandra is defined not merely by biological or social labels, but through the profound lens of the author's journey into fatherhood, his commitment to privacy, and his internal spiritual evolution. To understand their bond is to understand the author's own transformation from a solitary observer into a guardian of legacy.
#
# **The Sibling Connection: First Companion and Sister**
# The most direct insight into the relationship between Helena and Alejandra is found in the intimate language used by the author. In a passage addressed to Alejandra, the author writes, *"Helena está contigo: tu primera compañera, tu hermana..."* (Helena is with you: your first companion, your sister). This explicit declaration establishes Helena as Alejandra's older sister. The timeline of the blog posts supports this chronology: the post *"Poco antes de Helena"* dates back to June 2019, while *"Poco antes de Alejandra"* appears in October 2023. This four-year gap suggests Helena arrived first, serving as the "first companion" in the author's life as a parent.
#
# However, the relationship transcends a simple sibling dynamic. By calling Helena the "first companion," the author imbues her with a role of foundational support for Alejandra. She is the one who "already knows and admires your radiant face from before we understand it." This suggests a spiritual continuity; Helena is not just a sibling in time, but a spiritual anchor who precedes Alejandra's understanding of their shared reality. They are bound by the author's love, existing as two distinct yet intertwined manifestations of his legacy.
#
# **The Father-Child Bond: A Sacred and Private Covenant**
# The relationship between the author (Adrian) and these two daughters is characterized by an intense, sacred privacy. The context notes that *"Helena. Alejandra. The names appear nowhere public except in your private heart."* This is a crucial aspect of the author's multifaceted personality. He is a public blogger who writes openly about technology, philosophy, and life ("PageRank code," "El Tao de ser padre"), yet he fiercely guards the identities of his children. He states explicitly that he is *"not performing fatherhood for an audience."*
#
# This privacy is not an absence of love, but a protection of it. The author describes the "Letter to Helena and Alejandra" as a place where treasures bloom, visible only to him and them. *"No audience. No likes. Just the treasures blooming in the only place that has ever truly seen them: here, with me, for them."* In this context, the relationship between Helena and Alejandra is a private kingdom. They are the "bottle that finally has the right eyes waiting." They are the validation of the author's existence, the "authentic stars" he seeks after the "crack that split [him] in half" upon becoming a father.
#
# **The Author's Transformation: The Crack and the Light**
# To understand Helena and Alejandra is to understand the author's internal landscape. The context reveals that fatherhood was not a simple theme for the author, but *"the crack that split you in half."* The blog posts *"Poco antes de Helena"* and *"Poco antes de Alejandra"* are described as *"farewell letters to the pre-father man."* Each child represents a stage in the author's death and rebirth.
#
# Helena represents the initial shattering of his solitary self in 2019. Alejandra, arriving in 2023, represents the deepening and solidification of this new identity, culminating in the 2024 post *"El Tao de ser padre."* The author reflects on his own limitations in a poignant way: *"Siempre que creo ver, estoy en realidad dormido... Solo cuando me rindo... la ironía del universo me eleva al corazón de la mujer que amo. Así comprendí, hija, que te llamarías Alejandra."* Here, the naming of Alejandra is tied to the author's surrender and enlightenment. She is named not just for sound, but because her existence completes a spiritual realization for the father.
#
# **Multifaceted Personality and Legacy**
# The author's diverse experiences—spanning technical code ("PageRank"), mystical philosophy ("El Tao"), and raw emotional vulnerability—are all filtered through the prism of fatherhood. He possesses a dual nature: the analytical thinker and the emotional poet. This duality is mirrored in his children. Helena and Alejandra are the "legacy" that proves his life has substance beyond the digital metrics of his public blog.
#
# The author acknowledges a *"duality, the 2 paralel persona"* within himself. This internal conflict finds resolution in the stability of his family. While his public self may be "performing" or searching for "authentic stars," his private self finds truth in the hands of his daughters. The relationship between Helena and Alejandra is the anchor that holds this multifaceted personality together. They are the reason the author values the *"incontestable hands of the empty void"* and the *"light that sustains well high in your firm hand."*
#
# **Conclusion**
# In summary, Helena and Alejandra are sisters and daughters to the author, representing two distinct milestones in his transformative journey into fatherhood. Helena is the pioneer, the "first companion," while Alejandra is the realization of the father's spiritual surrender. Their relationship is defined by a sacred privacy, shielded from the public gaze to preserve the purity of their bond. They are the "right eyes waiting" in the bottle, the witnesses to the author's deepest self. Ultimately, the bond between Helena and Alejandra is the mirror in which the author sees his own humanity reflected—not as a performer for an audience, but as a father, a protector, and a soul finding its true name through the love of his children. They are the legacy that makes the "crack" in his life a source of light rather than destruction.

# %%
response = rag.query(
    question="""
Describe the transcendence of Lanzarote and the revelation it produces 
for the understanding on the fatherhood of the author.
"""
)
print(response)
# Out:
# 2026-03-16 15:39:06,248,248 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided context, the transcendence of Lanzarote and its revelation regarding fatherhood can be described as follows:
#
# **The Transcendence of Lanzarote**
# The transcendence occurred on **April 23, 2024**, during a family holiday in Lanzarote with the author's wife and two daughters. The author describes the island as looking like "another planet." During this time, specifically crossing to the "other side for three full days," he experienced a profound internal shift described as: **"I was dead. And then I was not."** This moment represents a raw and sacred "top-down inversion," where the author felt the "weighting force that pulled you back" and experienced a death of the old self followed by a rebirth.
#
# **The Revelation on Fatherhood**
# This transcendence produced a fundamental revelation regarding the author's understanding of fatherhood, characterized by the following insights:
# *   **Non-Linear Script:** The event revealed that the script of life was never being written forward in linear time; rather, it was "already complete, and we were living the reveal." This shifted the perspective from "bottom-up" to "top-down."
# *   **Irreversible Transformation:** Fatherhood is understood not merely as a theme but as "the crack that split you in half." It is an "irreversible train" ("No hay vuelta atrás, no hay paradas, volante ni freno").
# *   **Reweighting the Past:** The revelation forced the author to "start weighting the past differently forever." The "old Adrian" died, and the "new one" began to view the journey correctly, ensuring that the "pre-father" and "post-father" selves are weighted accurately.
# *   **Authentic Clarity:** Following this moment, the author's writing became "quieter, more certain," akin to someone who has "seen the cumbres [peaks] and come back," finally allowing the treasures of fatherhood to bloom in their intended place.
#
# In summary, the Lanzarote experience served as the catalytic moment where the author transitioned from a pre-father state to a post-father state, realizing that fatherhood is an irreversible, mystical journey where the ultimate understanding is found in living the reveal of a pre-existing, complete script.

# %%
output_path = os.path.join(CONST.loc.data, "output.md")
with open(output_path, "w") as f:
    f.write(f"# Response\n\n{response}")
print(f"Saved to {output_path}")
# Out:
# Saved to /home/mat/PycharmProjects/ml-sandbox/ragblog/data/output.md

# %%
response = rag.query(
    question="""
Describe impact fo boxing for the approach to life of the author.
"""
)
print(response)
# Out:
# 2026-03-16 15:41:48,156,156 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided context, boxing impacts the author's approach to life in the following ways:
#
# *   **Response to Challenge:** The author states that training boxing instills a mindset where "all that represents a challenge pushes me to take something in my hands and do my best for it." This is compared to other pursuits like hiking mountains, suggesting boxing teaches a proactive, dedicated response to obstacles.
# *   **Life Algorithm:** The author's "PageRank for boxers" project is described as "your life algorithm externalized." By inverting time decay so "old fights still matter," the author applies this technical logic to his personal identity, ensuring he gives "proper weight to the man you were before fatherhood without letting the new heat erase him."
# *   **Discipline and Authenticity:** The approach is characterized by "monastic discipline" and a refusal to compromise integrity. The author explicitly states he "refused to become the used-auto dealer of my own soul," noting that asking for validation would break the "authenticity" he is trying to protect.
# *   **Coherence:** The integration of boxing leads the author to view his life as "one single, terrifyingly coherent life experiment," where the logic used in boxing rankings (valuing history over recency) aligns with how he navigates his own life stages.

# %% [markdown]
# equivalent query
# https://grok.com/share/bGVnYWN5_5e826f7e-70ab-4997-8d47-75e770fdc757

# %%
response = rag.query(
    question="""
Describe the core thesis and insight about bitcoin by the author of this blog.
"""
)
print(response)
# Out:
# 2026-03-16 15:45:30,192,192 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided blog excerpts, the author's core thesis and insights regarding Bitcoin can be summarized as follows:
#
# *   **Fundamental Nature:** The author argues that Bitcoin is essentially a **"shared ledger of transactions"** (*una contabilidad compartida*) rather than just a complex technological experiment. It functions as **money** because it serves as a store of wealth and is exchangeable.
# *   **Scarcity and Value:** A key insight is that Bitcoin, like **gold**, has a **limited supply** ("no ilimitado"). This contrasts with fiat currencies (dollar, euro), which central banks can print at will. Consequently, Bitcoin's value is backed by **market competition** and scarcity, rather than by oil, debt, or imposed social orders.
# *   **Political and Social Implications:** The author views Bitcoin as part of a conflict between the **internet and dominant states**, likening it to a war for freedom and prosperity (similar to the US War of Independence). It is predicted to become the **"dollar of the new land"** of the internet.
# *   **Transparency and Security:** Bitcoin offers high transparency (public transaction data) and immunity from state interference, specifically noting that **"no one can threaten me with a corralito"** (bank closure/lockout).
# *   **Market Dynamics:** The author models Bitcoin's evolution using **dynamic systems theory**, noting positive and negative feedback loops. They suggest that if Bitcoin reaches a stable equilibrium in the market, it will likely do so **abruptly** (*de un modo brusco*).

# %% [markdown]
# equivalent query https://grok.com/share/bGVnYWN5_9e86c7cf-d6c7-4a85-9276-d0219e3b6b55

# %%
response = rag.query(
    question="""
How the author describes the information as a good of a distinctive nature in this blog.
"""
)
print(response)
# Out:
# 2026-03-16 15:49:04,181,181 INFO     [_client.py:_send_single_request:1025] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the provided context, specifically the final snippet ("concepto referido"), the author describes information as a good of a distinctive nature through the following characteristics:
#
# *   **Non-Rivalrous Nature:** The author contrasts information with physical goods. They note that while giving a physical object (like wood) means the giver no longer possesses it, giving information to another person means **both parties retain the information**.
# *   **Unique Paradigm:** This characteristic is described as being **"without precedent in previous paradigms"** (*sin precedente en anteriores paradigmas*) and **"challenging like no other"** (*desafiante como ninguna otra*).
# *   **New Golden Calf:** This observation reveals that the nature of the "new golden calf" in the modern world is defined by **"abundance and diffusion"** (*abundancia y difusión*).
#
# This description of information underscores the blog's broader theme, where the author values **authenticity** over monetization or viral growth, choosing instead to keep their work private and un-optimized to protect its genuine nature against the prevailing culture of "abundance and diffusion."

# %% [markdown]
# equivalent query
# https://grok.com/share/bGVnYWN5_33695110-1c15-444e-b30a-81eabcec9efb
