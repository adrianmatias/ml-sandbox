INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/04/ahi-va-un-primer-fragmento-de-volcan.html
# 2026-03-16 15:59:57,047,47 INFO     [crawler.py:get_url_list:53] Next page URL: https://delightfulobservaciones.blogspot.com/search?updated-max=2012-04-22T09:32:00-07:00&max-results=7&start=45&by-date=false
# 2026-03-16 15:59:57,047,47 INFO     [crawler.py:get_url_list:34] Fetching https://delightfulobservaciones.blogspot.com/search?updated-max=2012-04-22T09:32:00-07:00&max-results=7&start=45&by-date=false
# 2026-03-16 15:59:57,304,304 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2012/02/soy-mas-rico-que-fernando-i-de-aragon.html
# 2026-03-16 15:59:57,305,305 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/11/waking-life.html
# 2026-03-16 15:59:57,305,305 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/11/europeos-del-centro-y-de-la-periferia.html
# 2026-03-16 15:59:57,305,305 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/10/gatos-de-schrondringer-pensamientos.html
# 2026-03-16 15:59:57,305,305 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/10/el-botin-miedo-amenaza-o-ambos.html
# 2026-03-16 15:59:57,305,305 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/10/sobre-la-consciencia.html
# 2026-03-16 15:59:57,305,305 INFO     [crawler.py:get_url_list:45] url: https://delightfulobservaciones.blogspot.com/2011/10/el-cambio-global-se-irradia-desde-el-15.html
# 2026-03-16 15:59:57,306,306 INFO     [crawler.py:get_url_list:55] No more pages found.
# 2026-03-16 16:00:15,216,216 INFO     [crawler.py:write:70] path_file: /home/mat/PycharmProjects/ml-sandbox/ragblog/data/blog.jsonl
# 2026-03-16 16:00:15,218,218 INFO     [doc_loader.py:__init__:0] DocLoader: {}
# 2026-03-16 16:00:15,249,249 INFO     [vector_db.py:save:29] doc_list_count=904
# 2026-03-16 16:00:15,260,260 INFO     [posthog.py:__init__:22] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-03-16 16:02:46,814,814 INFO     [rag.py:__init__:0] Rag: {'aug': <LLM.QWEN_3_5_27B_Q3: 'unsloth/Qwen3.5-27B-GGUF:Q3_K_S'>, 'vector_db': <langchain_chroma.vectorstores.Chroma object at 0x7ed861335e20>, 'chain': {
#   context: VectorStoreRetriever(tags=['Chroma', 'OllamaEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x7ed861335e20>, search_kwargs={'k': 10})
#            | RunnableLambda(format_docs),
#   question: RunnablePassthrough()
# }
# | ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know."), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Question: {question}\n\nContext: {context}\n\nAnswer:'), additional_kwargs={})])
# | ChatOpenAI(profile={}, client=<openai.resources.chat.completions.completions.Completions object at 0x7ed861308da0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7ed854a13140>, root_client=<openai.OpenAI object at 0x7ed8607dce30>, root_async_client=<openai.AsyncOpenAI object at 0x7ed861379340>, model_name='unsloth/Qwen3.5-27B-GGUF:Q3_K_S', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='http://127.0.0.1:8080/v1', max_tokens=4096)
# | StrOutputParser()}

# %%
response = rag.query(
    question="""
Describe the relation between Helena and Alejandra.
Consider the author's diverse experiences and multifaceted personality,
reflecting on traits that are evident across their various blog posts.
Provide a detailed and thoughtful response.
Ensure your answer is profound and sufficiently long,
offering deep insights and personal reflections.
"""
)
print(response)
# Out:
# 2026-03-16 16:02:46,960,960 INFO     [_base_client.py:_sleep_for_retry:1094] Retrying request to /chat/completions in 0.451398 seconds
# 2026-03-16 16:02:47,414,414 INFO     [_base_client.py:_sleep_for_retry:1094] Retrying request to /chat/completions in 0.873147 seconds
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /usr/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/openai/_base_client.py:1005, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1004 try:
# -> 1005     response = self._client.send(
#    1006         request,
#    1007         stream=stream or self._should_stream_response_body(request=request),
#    1008         **kwargs,
#    1009     )
#    1010 except httpx.TimeoutException as err:
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File /usr/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response = rag.query(
#       2     question="""
#       3 Describe the relation between Helena and Alejandra.
#       4 Consider the author's diverse experiences and multifaceted personality,
#       5 reflecting on traits that are evident across their various blog posts.
#       6 Provide a detailed and thoughtful response.
#       7 Ensure your answer is profound and sufficiently long,
#       8 offering deep insights and personal reflections.
#       9 """
#      10 )
#      11 print(response)
#
# File ~/PycharmProjects/ml-sandbox/ragblog/src/rag.py:64, in Rag.query(self, question)
#      63 def query(self, question: str):
# ---> 64     response = self.chain.invoke(question)
#      65     if response and response.strip():
#      66         return response
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3157, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3155                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156             else:
# -> 3157                 input_ = context.run(step.invoke, input_, config)
#    3158 # finish the root run
#    3159 except BaseException as e:
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1121, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1112 @override
#    1113 def generate_prompt(
#    1114     self,
#    (...)   1118     **kwargs: Any,
#    1119 ) -> LLMResult:
#    1120     prompt_messages = [p.to_messages() for p in prompts]
# -> 1121     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:931, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     928 for i, m in enumerate(input_messages):
#     929     try:
#     930         results.append(
# --> 931             self._generate_with_cache(
#     932                 m,
#     933                 stop=stop,
#     934                 run_manager=run_managers[i] if run_managers else None,
#     935                 **kwargs,
#     936             )
#     937         )
#     938     except BaseException as e:
#     939         if run_managers:
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1233, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1231     result = generate_from_stream(iter(chunks))
#    1232 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1233     result = self._generate(
#    1234         messages, stop=stop, run_manager=run_manager, **kwargs
#    1235     )
#    1236 else:
#    1237     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1422, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1420     _handle_openai_bad_request(e)
#    1421 except openai.APIError as e:
# -> 1422     _handle_openai_api_error(e)
#    1423 except Exception as e:
#    1424     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1417, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1410         return _construct_lc_result_from_responses_api(
#    1411             response,
#    1412             schema=original_schema_obj,
#    1413             metadata=generation_info,
#    1414             output_version=self.output_version,
#    1415         )
#    1416     else:
# -> 1417         raw_response = self.client.with_raw_response.create(**payload)
#    1418         response = raw_response.parse()
#    1419 except openai.BadRequestError as e:
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1204, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1157 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1158 def create(
#    1159     self,
#    (...)   1201     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1202 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1203     validate_response_format(response_format)
# -> 1204     return self._post(
#    1205         "/chat/completions",
#    1206         body=maybe_transform(
#    1207             {
#    1208                 "messages": messages,
#    1209                 "model": model,
#    1210                 "audio": audio,
#    1211                 "frequency_penalty": frequency_penalty,
#    1212                 "function_call": function_call,
#    1213                 "functions": functions,
#    1214                 "logit_bias": logit_bias,
#    1215                 "logprobs": logprobs,
#    1216                 "max_completion_tokens": max_completion_tokens,
#    1217                 "max_tokens": max_tokens,
#    1218                 "metadata": metadata,
#    1219                 "modalities": modalities,
#    1220                 "n": n,
#    1221                 "parallel_tool_calls": parallel_tool_calls,
#    1222                 "prediction": prediction,
#    1223                 "presence_penalty": presence_penalty,
#    1224                 "prompt_cache_key": prompt_cache_key,
#    1225                 "prompt_cache_retention": prompt_cache_retention,
#    1226                 "reasoning_effort": reasoning_effort,
#    1227                 "response_format": response_format,
#    1228                 "safety_identifier": safety_identifier,
#    1229                 "seed": seed,
#    1230                 "service_tier": service_tier,
#    1231                 "stop": stop,
#    1232                 "store": store,
#    1233                 "stream": stream,
#    1234                 "stream_options": stream_options,
#    1235                 "temperature": temperature,
#    1236                 "tool_choice": tool_choice,
#    1237                 "tools": tools,
#    1238                 "top_logprobs": top_logprobs,
#    1239                 "top_p": top_p,
#    1240                 "user": user,
#    1241                 "verbosity": verbosity,
#    1242                 "web_search_options": web_search_options,
#    1243             },
#    1244             completion_create_params.CompletionCreateParamsStreaming
#    1245             if stream
#    1246             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1247         ),
#    1248         options=make_request_options(
#    1249             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1250         ),
#    1251         cast_to=ChatCompletion,
#    1252         stream=stream or False,
#    1253         stream_cls=Stream[ChatCompletionChunk],
#    1254     )
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/PycharmProjects/ml-sandbox/ragblog/.venv/lib/python3.12/site-packages/openai/_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1034         continue
#    1036     log.debug("Raising connection error")
# -> 1037     raise APIConnectionError(request=request) from err
#    1039 log.debug(
#    1040     'HTTP Response: %s %s "%i %s" %s',
#    1041     request.method,
#    (...)   1045     response.headers,
#    1046 )
#    1047 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
response = rag.query(
    question="""
Describe the transcendence of Lanzarote and the revelation it produces 
for the understanding on the fatherhood of the author.
"""
)
print(response)

# %%
output_path = os.path.join(CONST.loc.data, "output.md")
with open(output_path, "w") as f:
    f.write(f"# Response\n\n{response}")
print(f"Saved to {output_path}")

# %%
response = rag.query(
    question="""
Describe impact fo boxing for the approach to life of the author.
"""
)
print(response)

# %% [markdown]
# equivalent query
# https://grok.com/share/bGVnYWN5_5e826f7e-70ab-4997-8d47-75e770fdc757

# %%
response = rag.query(
    question="""
Describe the core thesis and insight about bitcoin by the author of this blog.
"""
)
print(response)

# %% [markdown]
# equivalent query https://grok.com/share/bGVnYWN5_9e86c7cf-d6c7-4a85-9276-d0219e3b6b55

# %%
response = rag.query(
    question="""
How the author describes the information as a good of a distinctive nature in this blog.
"""
)
print(response)

# %% [markdown]
# equivalent query
# https://grok.com/share/bGVnYWN5_33695110-1c15-444e-b30a-81eabcec9efb
